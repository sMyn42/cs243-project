# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# %%
class LayoutDataProcessor:
    def __init__(self, directory, split):
        self.directory = os.path.join(directory, split)
        self.data = []
        self.feature_occurrences = {}

    def load_data(self):
        for filename in tqdm(os.listdir(self.directory)):
            filepath = os.path.join(self.directory, filename)
            self.process_file(filepath, filename)
        self.calculate_occurrence_rates()

    def process_file(self, filepath, filename):
        data = np.load(filepath)
        node_config_ids = data['node_config_ids']
        node_config_feat = data['node_config_feat']
        config_runtime = data['config_runtime']
        node_feat = data['node_feat']
        node_opcode = data['node_opcode']

        # Initialize feature occurrence tracking if not done yet
        if not self.feature_occurrences:
            for i in range(node_config_feat.shape[2]):  # For each feature in node_config_feat
                self.feature_occurrences[f"feature_{i}"] = {}

        # Process each configuration
        for i in range(len(config_runtime)):
            # Configuration feature array for the current configuration
            current_config_features = node_config_feat[i, :, :]

            # Append features to the data dictionary
            row = {
                'config_id': f"{filename}",
                'runtime': config_runtime[i],
            }

            for feature_index in range(current_config_features.shape[1]):
                feature_name = f"feature_{feature_index}"
                feature_value = current_config_features[0, feature_index]  # Assuming features are not multi-dimensional
                row[feature_name] = feature_value

                # Update occurrence counts for each feature
                self.feature_occurrences[feature_name].setdefault(feature_value, 0)
                self.feature_occurrences[feature_name][feature_value] += 1

            self.data.append(row)

    def calculate_occurrence_rates(self):
        for row in self.data:
            for feature_name, occurrences in self.feature_occurrences.items():
                feature_value = row[feature_name]
                total_occurrences = sum(occurrences.values())
                row[feature_name + '_rate'] = occurrences[feature_value] / total_occurrences

    def get_dataframe(self):
        return pd.DataFrame(self.data)

# %%
processor = LayoutDataProcessor('/kaggle/input/predict-ai-model-runtime/npz_all/npz/layout/xla/default', 'valid')
processor.load_data()
df_valid = processor.get_dataframe()
# Out:
# 100%|██████████| 7/7 [00:07<00:00,  1.09s/it]

# %%
df_valid.columns

# %%
import warnings

# Use this at the beginning of the cell where you want to suppress future warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Iterate over each config_id and scale the target column within each group
for config_id in tqdm(df_valid['config_id'].unique()):
    # Selecting the rows corresponding to the current config_id
    idx = df_valid['config_id'] == config_id
    # Scaling the target column for the current group
    df_valid.loc[idx, 'runtime'] = scaler.fit_transform(df_valid.loc[idx, ['runtime']])
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 80.42it/s]

# %%
df_valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66021 entries, 0 to 66020
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   config_id        66021 non-null  object
#  1   runtime          66021 non-null  float64
#  2   feature_0        66021 non-null  float32
#  3   feature_1        66021 non-null  float32
#  4   feature_2        66021 non-null  float32
#  5   feature_3        66021 non-null  float32
#  6   feature_4        66021 non-null  float32
#  7   feature_5        66021 non-null  float32
#  8   feature_6        66021 non-null  float32
#  9   feature_7        66021 non-null  float32
#  10  feature_8        66021 non-null  float32
#  11  feature_9        66021 non-null  float32
#  12  feature_10       66021 non-null  float32
#  13  feature_11       66021 non-null  float32
#  14  feature_12       66021 non-null  float32
#  15  feature_13       66021 non-null  float32
#  16  feature_14       66021 non-null  float32
#  17  feature_15       66021 non-null  float32
#  18  feature_16       66021 non-null  float32
#  19  feature_17       66021 non-null  float32
#  20  feature_0_rate   66021 non-null  float64
#  21  feature_1_rate   66021 non-null  float64
#  22  feature_2_rate   66021 non-null  float64
#  23  feature_3_rate   66021 non-null  float64
#  24  feature_4_rate   66021 non-null  float64
#  25  feature_5_rate   66021 non-null  float64
#  26  feature_6_rate   66021 non-null  float64
#  27  feature_7_rate   66021 non-null  float64
#  28  feature_8_rate   66021 non-null  float64
#  29  feature_9_rate   66021 non-null  float64
#  30  feature_10_rate  66021 non-null  float64
#  31  feature_11_rate  66021 non-null  float64
#  32  feature_12_rate  66021 non-null  float64
#  33  feature_13_rate  66021 non-null  float64
#  34  feature_14_rate  66021 non-null  float64
#  35  feature_15_rate  66021 non-null  float64
#  36  feature_16_rate  66021 non-null  float64
#  37  feature_17_rate  66021 non-null  float64
# dtypes: float32(18), float64(19), object(1)
# memory usage: 14.6+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

# %%
unique_config_ids = df_valid['config_id'].unique()
train_config_ids, test_config_ids = train_test_split(unique_config_ids, test_size=0.1, random_state=42)

# Creating train and test dataframes based on config_id
train_df = df_valid[df_valid['config_id'].isin(train_config_ids)]
test_df = df_valid[df_valid['config_id'].isin(test_config_ids)]

# Separating features and target variable
X_train = train_df.drop(['config_id', 'runtime',], axis=1)
y_train = train_df['runtime']
X_test = test_df.drop(['config_id', 'runtime',], axis=1)
y_test = test_df['runtime']

# %%
# !pip install LightGBM
from lightgbm import LGBMRegressor
# Out:
# Requirement already satisfied: LightGBM in /opt/conda/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from LightGBM) (0.41.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from LightGBM) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from LightGBM) (1.11.4)
# Requirement already satisfied: scikit-learn!=0.22.0 in /opt/conda/lib/python3.10/site-packages (from LightGBM) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn!=0.22.0->LightGBM) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn!=0.22.0->LightGBM) (3.2.0)
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
df_valid['runtime'].describe()
# Out:
# count    66021.000000
# mean         0.072605
# std          0.192265
# min          0.000000
# 25%          0.001642
# 50%          0.003572
# 75%          0.012358
# max          1.000000
# Name: runtime, dtype: float64

# %%
# Training models
lin_reg = LinearRegression().fit(X_train, y_train)

alpha_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# Setting up GridSearchCV for Lasso Regression
lasso = Lasso()
grid_search_lasso = GridSearchCV(estimator=lasso, param_grid=alpha_grid, cv=3, scoring='neg_mean_squared_error',verbose=4)
grid_search_lasso.fit(X_train, y_train)
lasso_reg = grid_search_lasso.best_estimator_
print("Lasso Alpha")
print(grid_search_lasso.best_params_['alpha'])

ridge = Ridge()
grid_search_ridge = GridSearchCV(estimator=ridge, param_grid=alpha_grid, cv=3, scoring='neg_mean_squared_error',verbose=4)
grid_search_ridge.fit(X_train, y_train)
ridge_reg = grid_search_ridge.best_estimator_
print("Ridge Alpha")
print(grid_search_ridge.best_params_['alpha'])

# Making predictions
train_predictions_lin = lin_reg.predict(X_train)
train_predictions_lasso = lasso_reg.predict(X_train)
train_predictions_ridge = ridge_reg.predict(X_train)

predictions_lin = lin_reg.predict(X_test)
predictions_lasso = lasso_reg.predict(X_test)
predictions_ridge = ridge_reg.predict(X_test)

# Calculating R² scores
r2_lin = r2_score(y_test, predictions_lin)
r2_lasso = r2_score(y_test, predictions_lasso)
r2_ridge = r2_score(y_test, predictions_ridge)

r2_train_lin = r2_score(y_train, train_predictions_lin)
r2_train_lasso = r2_score(y_train, train_predictions_lasso)
r2_train_ridge = r2_score(y_train, train_predictions_ridge)

print("R² Scores Train:")
print(f"Linear Regression: {r2_train_lin}")
print(f"Lasso Regression: {r2_train_lasso}")
print(f"Ridge Regression: {r2_train_ridge}")

print("R² Scores Test:")
print(f"Linear Regression: {r2_lin}")
print(f"Lasso Regression: {r2_lasso}")
print(f"Ridge Regression: {r2_ridge}")
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV 1/3] END ......................alpha=0.001;, score=-0.026 total time=   0.1s
# [CV 2/3] END ......................alpha=0.001;, score=-0.033 total time=   0.1s
# [CV 3/3] END ......................alpha=0.001;, score=-0.049 total time=   0.1s
# [CV 1/3] END .......................alpha=0.01;, score=-0.026 total time=   0.1s
# [CV 2/3] END .......................alpha=0.01;, score=-0.033 total time=   0.1s
# [CV 3/3] END .......................alpha=0.01;, score=-0.050 total time=   0.1s
# [CV 1/3] END ........................alpha=0.1;, score=-0.026 total time=   0.1s
# [CV 2/3] END ........................alpha=0.1;, score=-0.033 total time=   0.1s
# [CV 3/3] END ........................alpha=0.1;, score=-0.050 total time=   0.1s
# [CV 1/3] END ..........................alpha=1;, score=-0.026 total time=   0.1s
# [CV 2/3] END ..........................alpha=1;, score=-0.033 total time=   0.1s
# [CV 3/3] END ..........................alpha=1;, score=-0.050 total time=   0.1s
# [CV 1/3] END .........................alpha=10;, score=-0.026 total time=   0.1s
# [CV 2/3] END .........................alpha=10;, score=-0.033 total time=   0.1s
# [CV 3/3] END .........................alpha=10;, score=-0.050 total time=   0.0s
# [CV 1/3] END ........................alpha=100;, score=-0.026 total time=   0.0s
# [CV 2/3] END ........................alpha=100;, score=-0.033 total time=   0.0s
# [CV 3/3] END ........................alpha=100;, score=-0.050 total time=   0.1s
# Lasso Alpha
# 0.001
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV 1/3] END ......................alpha=0.001;, score=-0.026 total time=   0.0s
# [CV 2/3] END ......................alpha=0.001;, score=-0.033 total time=   0.0s
# [CV 3/3] END ......................alpha=0.001;, score=-0.055 total time=   0.0s
# [CV 1/3] END .......................alpha=0.01;, score=-0.026 total time=   0.1s
# [CV 2/3] END .......................alpha=0.01;, score=-0.033 total time=   0.0s
# [CV 3/3] END .......................alpha=0.01;, score=-0.055 total time=   0.0s
# [CV 1/3] END ........................alpha=0.1;, score=-0.026 total time=   0.0s
# [CV 2/3] END ........................alpha=0.1;, score=-0.033 total time=   0.0s
# [CV 3/3] END ........................alpha=0.1;, score=-0.055 total time=   0.0s
# [CV 1/3] END ..........................alpha=1;, score=-0.026 total time=   0.0s
# [CV 2/3] END ..........................alpha=1;, score=-0.033 total time=   0.0s
# [CV 3/3] END ..........................alpha=1;, score=-0.054 total time=   0.0s
# [CV 1/3] END .........................alpha=10;, score=-0.026 total time=   0.0s
# [CV 2/3] END .........................alpha=10;, score=-0.033 total time=   0.0s
# [CV 3/3] END .........................alpha=10;, score=-0.054 total time=   0.0s
# [CV 1/3] END ........................alpha=100;, score=-0.026 total time=   0.0s
# [CV 2/3] END ........................alpha=100;, score=-0.033 total time=   0.0s
# [CV 3/3] END ........................alpha=100;, score=-0.050 total time=   0.0s
# Ridge Alpha
# 100
# R² Scores Train:
# Linear Regression: 0.05271544103444703
# Lasso Regression: 0.05123535641852761
# Ridge Regression: 0.05270875159139332
# R² Scores Test:
# Linear Regression: 0.27265398344931957
# Lasso Regression: 0.25694598313888717
# Ridge Regression: 0.270174915468389

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %%
param_dist = {
    'num_leaves': sp_randint(3, 50), 
    'min_child_samples': sp_randint(5, 500), 
    'min_child_weight': sp_uniform(0.01, 0.1),
    'subsample': sp_uniform(0.8, 0.2),
    'colsample_bytree': sp_uniform(0.8, 0.2),
    'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10],
    'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50],
    'learning_rate': [0.001, 0.005, 0.01, 0.05, 0.1, 0.2],
    'n_estimators': [100, 250, 500, 1000, 1500]
}

# %%
lgbm = LGBMRegressor(device='gpu', gpu_device=0)

# %%
random_search = RandomizedSearchCV(lgbm, param_distributions=param_dist, n_iter=25, cv=4, scoring='neg_mean_squared_error', verbose=4)
random_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 25 candidates, totalling 100 fits
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.896350649181155, learning_rate=0.2, min_child_samples=478, min_child_weight=0.030930281034185818, n_estimators=1500, num_leaves=13, reg_alpha=7, reg_lambda=20, subsample=0.839600787134435;, score=-0.028 total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.896350649181155, learning_rate=0.2, min_child_samples=478, min_child_weight=0.030930281034185818, n_estimators=1500, num_leaves=13, reg_alpha=7, reg_lambda=20, subsample=0.839600787134435;, score=-0.030 total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.896350649181155, learning_rate=0.2, min_child_samples=478, min_child_weight=0.030930281034185818, n_estimators=1500, num_leaves=13, reg_alpha=7, reg_lambda=20, subsample=0.839600787134435;, score=-0.037 total time=   1.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.896350649181155, learning_rate=0.2, min_child_samples=478, min_child_weight=0.030930281034185818, n_estimators=1500, num_leaves=13, reg_alpha=7, reg_lambda=20, subsample=0.839600787134435;, score=-0.049 total time=   1.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9021066713567868, learning_rate=0.01, min_child_samples=167, min_child_weight=0.08483087062602003, n_estimators=250, num_leaves=44, reg_alpha=0, reg_lambda=20, subsample=0.9893082638652807;, score=-0.028 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9021066713567868, learning_rate=0.01, min_child_samples=167, min_child_weight=0.08483087062602003, n_estimators=250, num_leaves=44, reg_alpha=0, reg_lambda=20, subsample=0.9893082638652807;, score=-0.030 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9021066713567868, learning_rate=0.01, min_child_samples=167, min_child_weight=0.08483087062602003, n_estimators=250, num_leaves=44, reg_alpha=0, reg_lambda=20, subsample=0.9893082638652807;, score=-0.037 total time=   1.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9021066713567868, learning_rate=0.01, min_child_samples=167, min_child_weight=0.08483087062602003, n_estimators=250, num_leaves=44, reg_alpha=0, reg_lambda=20, subsample=0.9893082638652807;, score=-0.105 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.889325703249665, learning_rate=0.001, min_child_samples=164, min_child_weight=0.05955805843815375, n_estimators=500, num_leaves=6, reg_alpha=2, reg_lambda=20, subsample=0.9034081897452804;, score=-0.028 total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.889325703249665, learning_rate=0.001, min_child_samples=164, min_child_weight=0.05955805843815375, n_estimators=500, num_leaves=6, reg_alpha=2, reg_lambda=20, subsample=0.9034081897452804;, score=-0.030 total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.889325703249665, learning_rate=0.001, min_child_samples=164, min_child_weight=0.05955805843815375, n_estimators=500, num_leaves=6, reg_alpha=2, reg_lambda=20, subsample=0.9034081897452804;, score=-0.039 total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.889325703249665, learning_rate=0.001, min_child_samples=164, min_child_weight=0.05955805843815375, n_estimators=500, num_leaves=6, reg_alpha=2, reg_lambda=20, subsample=0.9034081897452804;, score=-0.055 total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9456490914722071, learning_rate=0.05, min_child_samples=379, min_child_weight=0.03020193708145394, n_estimators=250, num_leaves=25, reg_alpha=10, reg_lambda=50, subsample=0.9831187844566914;, score=-0.028 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9456490914722071, learning_rate=0.05, min_child_samples=379, min_child_weight=0.03020193708145394, n_estimators=250, num_leaves=25, reg_alpha=10, reg_lambda=50, subsample=0.9831187844566914;, score=-0.030 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9456490914722071, learning_rate=0.05, min_child_samples=379, min_child_weight=0.03020193708145394, n_estimators=250, num_leaves=25, reg_alpha=10, reg_lambda=50, subsample=0.9831187844566914;, score=-0.039 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9456490914722071, learning_rate=0.05, min_child_samples=379, min_child_weight=0.03020193708145394, n_estimators=250, num_leaves=25, reg_alpha=10, reg_lambda=50, subsample=0.9831187844566914;, score=-0.047 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9961676915049176, learning_rate=0.1, min_child_samples=237, min_child_weight=0.09198541565307419, n_estimators=500, num_leaves=34, reg_alpha=0.1, reg_lambda=0, subsample=0.9630288148888715;, score=-0.028 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9961676915049176, learning_rate=0.1, min_child_samples=237, min_child_weight=0.09198541565307419, n_estimators=500, num_leaves=34, reg_alpha=0.1, reg_lambda=0, subsample=0.9630288148888715;, score=-0.030 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9961676915049176, learning_rate=0.1, min_child_samples=237, min_child_weight=0.09198541565307419, n_estimators=500, num_leaves=34, reg_alpha=0.1, reg_lambda=0, subsample=0.9630288148888715;, score=-0.037 total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9961676915049176, learning_rate=0.1, min_child_samples=237, min_child_weight=0.09198541565307419, n_estimators=500, num_leaves=34, reg_alpha=0.1, reg_lambda=0, subsample=0.9630288148888715;, score=-0.047 total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9245600328863485, learning_rate=0.1, min_child_samples=89, min_child_weight=0.09124233208386649, n_estimators=1000, num_leaves=37, reg_alpha=0, reg_lambda=5, subsample=0.8449345123024147;, score=-0.028 total time=   2.0s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9245600328863485, learning_rate=0.1, min_child_samples=89, min_child_weight=0.09124233208386649, n_estimators=1000, num_leaves=37, reg_alpha=0, reg_lambda=5, subsample=0.8449345123024147;, score=-0.030 total time=   2.0s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9245600328863485, learning_rate=0.1, min_child_samples=89, min_child_weight=0.09124233208386649, n_estimators=1000, num_leaves=37, reg_alpha=0, reg_lambda=5, subsample=0.8449345123024147;, score=-0.037 total time=   2.2s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9245600328863485, learning_rate=0.1, min_child_samples=89, min_child_weight=0.09124233208386649, n_estimators=1000, num_leaves=37, reg_alpha=0, reg_lambda=5, subsample=0.8449345123024147;, score=-0.119 total time=   1.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8727696547732422, learning_rate=0.05, min_child_samples=10, min_child_weight=0.025147535963763748, n_estimators=1500, num_leaves=39, reg_alpha=0.1, reg_lambda=50, subsample=0.9830336199687238;, score=-0.028 total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8727696547732422, learning_rate=0.05, min_child_samples=10, min_child_weight=0.025147535963763748, n_estimators=1500, num_leaves=39, reg_alpha=0.1, reg_lambda=50, subsample=0.9830336199687238;, score=-0.030 total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8727696547732422, learning_rate=0.05, min_child_samples=10, min_child_weight=0.025147535963763748, n_estimators=1500, num_leaves=39, reg_alpha=0.1, reg_lambda=50, subsample=0.9830336199687238;, score=-0.037 total time=   1.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8727696547732422, learning_rate=0.05, min_child_samples=10, min_child_weight=0.025147535963763748, n_estimators=1500, num_leaves=39, reg_alpha=0.1, reg_lambda=50, subsample=0.9830336199687238;, score=-0.119 total time=   1.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8474599068147742, learning_rate=0.05, min_child_samples=199, min_child_weight=0.03989207232139609, n_estimators=250, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.992250691621749;, score=-0.028 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8474599068147742, learning_rate=0.05, min_child_samples=199, min_child_weight=0.03989207232139609, n_estimators=250, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.992250691621749;, score=-0.030 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8474599068147742, learning_rate=0.05, min_child_samples=199, min_child_weight=0.03989207232139609, n_estimators=250, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.992250691621749;, score=-0.037 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8474599068147742, learning_rate=0.05, min_child_samples=199, min_child_weight=0.03989207232139609, n_estimators=250, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.992250691621749;, score=-0.119 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9112536225246706, learning_rate=0.2, min_child_samples=40, min_child_weight=0.06140374219063673, n_estimators=100, num_leaves=38, reg_alpha=2, reg_lambda=20, subsample=0.9846089013645382;, score=-0.028 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9112536225246706, learning_rate=0.2, min_child_samples=40, min_child_weight=0.06140374219063673, n_estimators=100, num_leaves=38, reg_alpha=2, reg_lambda=20, subsample=0.9846089013645382;, score=-0.030 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9112536225246706, learning_rate=0.2, min_child_samples=40, min_child_weight=0.06140374219063673, n_estimators=100, num_leaves=38, reg_alpha=2, reg_lambda=20, subsample=0.9846089013645382;, score=-0.037 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9112536225246706, learning_rate=0.2, min_child_samples=40, min_child_weight=0.06140374219063673, n_estimators=100, num_leaves=38, reg_alpha=2, reg_lambda=20, subsample=0.9846089013645382;, score=-0.117 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8914864410852232, learning_rate=0.01, min_child_samples=420, min_child_weight=0.08293299329208687, n_estimators=100, num_leaves=38, reg_alpha=0.1, reg_lambda=50, subsample=0.8560028484092453;, score=-0.028 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8914864410852232, learning_rate=0.01, min_child_samples=420, min_child_weight=0.08293299329208687, n_estimators=100, num_leaves=38, reg_alpha=0.1, reg_lambda=50, subsample=0.8560028484092453;, score=-0.030 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8914864410852232, learning_rate=0.01, min_child_samples=420, min_child_weight=0.08293299329208687, n_estimators=100, num_leaves=38, reg_alpha=0.1, reg_lambda=50, subsample=0.8560028484092453;, score=-0.041 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8914864410852232, learning_rate=0.01, min_child_samples=420, min_child_weight=0.08293299329208687, n_estimators=100, num_leaves=38, reg_alpha=0.1, reg_lambda=50, subsample=0.8560028484092453;, score=-0.048 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8241073551366789, learning_rate=0.01, min_child_samples=314, min_child_weight=0.0502967901869884, n_estimators=100, num_leaves=43, reg_alpha=5, reg_lambda=10, subsample=0.987928573024888;, score=-0.028 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8241073551366789, learning_rate=0.01, min_child_samples=314, min_child_weight=0.0502967901869884, n_estimators=100, num_leaves=43, reg_alpha=5, reg_lambda=10, subsample=0.987928573024888;, score=-0.030 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8241073551366789, learning_rate=0.01, min_child_samples=314, min_child_weight=0.0502967901869884, n_estimators=100, num_leaves=43, reg_alpha=5, reg_lambda=10, subsample=0.987928573024888;, score=-0.038 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8241073551366789, learning_rate=0.01, min_child_samples=314, min_child_weight=0.0502967901869884, n_estimators=100, num_leaves=43, reg_alpha=5, reg_lambda=10, subsample=0.987928573024888;, score=-0.048 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8325774070368819, learning_rate=0.005, min_child_samples=301, min_child_weight=0.08862657142509456, n_estimators=1000, num_leaves=3, reg_alpha=5, reg_lambda=50, subsample=0.9654843686330941;, score=-0.028 total time=   1.0s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8325774070368819, learning_rate=0.005, min_child_samples=301, min_child_weight=0.08862657142509456, n_estimators=1000, num_leaves=3, reg_alpha=5, reg_lambda=50, subsample=0.9654843686330941;, score=-0.030 total time=   2.1s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8325774070368819, learning_rate=0.005, min_child_samples=301, min_child_weight=0.08862657142509456, n_estimators=1000, num_leaves=3, reg_alpha=5, reg_lambda=50, subsample=0.9654843686330941;, score=-0.037 total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8325774070368819, learning_rate=0.005, min_child_samples=301, min_child_weight=0.08862657142509456, n_estimators=1000, num_leaves=3, reg_alpha=5, reg_lambda=50, subsample=0.9654843686330941;, score=-0.047 total time=   1.2s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9205885409354827, learning_rate=0.005, min_child_samples=94, min_child_weight=0.07344533710106965, n_estimators=100, num_leaves=42, reg_alpha=0, reg_lambda=20, subsample=0.9939284240090835;, score=-0.028 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9205885409354827, learning_rate=0.005, min_child_samples=94, min_child_weight=0.07344533710106965, n_estimators=100, num_leaves=42, reg_alpha=0, reg_lambda=20, subsample=0.9939284240090835;, score=-0.030 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9205885409354827, learning_rate=0.005, min_child_samples=94, min_child_weight=0.07344533710106965, n_estimators=100, num_leaves=42, reg_alpha=0, reg_lambda=20, subsample=0.9939284240090835;, score=-0.039 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9205885409354827, learning_rate=0.005, min_child_samples=94, min_child_weight=0.07344533710106965, n_estimators=100, num_leaves=42, reg_alpha=0, reg_lambda=20, subsample=0.9939284240090835;, score=-0.055 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9646337245134845, learning_rate=0.05, min_child_samples=47, min_child_weight=0.03165656951026338, n_estimators=100, num_leaves=32, reg_alpha=1, reg_lambda=0, subsample=0.8800832762790125;, score=-0.028 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9646337245134845, learning_rate=0.05, min_child_samples=47, min_child_weight=0.03165656951026338, n_estimators=100, num_leaves=32, reg_alpha=1, reg_lambda=0, subsample=0.8800832762790125;, score=-0.030 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9646337245134845, learning_rate=0.05, min_child_samples=47, min_child_weight=0.03165656951026338, n_estimators=100, num_leaves=32, reg_alpha=1, reg_lambda=0, subsample=0.8800832762790125;, score=-0.037 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9646337245134845, learning_rate=0.05, min_child_samples=47, min_child_weight=0.03165656951026338, n_estimators=100, num_leaves=32, reg_alpha=1, reg_lambda=0, subsample=0.8800832762790125;, score=-0.117 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8130918338795144, learning_rate=0.001, min_child_samples=82, min_child_weight=0.021006005752519576, n_estimators=1000, num_leaves=40, reg_alpha=2, reg_lambda=1, subsample=0.9252048091047532;, score=-0.028 total time=   1.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8130918338795144, learning_rate=0.001, min_child_samples=82, min_child_weight=0.021006005752519576, n_estimators=1000, num_leaves=40, reg_alpha=2, reg_lambda=1, subsample=0.9252048091047532;, score=-0.030 total time=   1.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8130918338795144, learning_rate=0.001, min_child_samples=82, min_child_weight=0.021006005752519576, n_estimators=1000, num_leaves=40, reg_alpha=2, reg_lambda=1, subsample=0.9252048091047532;, score=-0.038 total time=   1.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8130918338795144, learning_rate=0.001, min_child_samples=82, min_child_weight=0.021006005752519576, n_estimators=1000, num_leaves=40, reg_alpha=2, reg_lambda=1, subsample=0.9252048091047532;, score=-0.073 total time=   1.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8036083300300916, learning_rate=0.1, min_child_samples=142, min_child_weight=0.045013327015118905, n_estimators=250, num_leaves=30, reg_alpha=0, reg_lambda=1, subsample=0.9298306856179669;, score=-0.028 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8036083300300916, learning_rate=0.1, min_child_samples=142, min_child_weight=0.045013327015118905, n_estimators=250, num_leaves=30, reg_alpha=0, reg_lambda=1, subsample=0.9298306856179669;, score=-0.030 total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8036083300300916, learning_rate=0.1, min_child_samples=142, min_child_weight=0.045013327015118905, n_estimators=250, num_leaves=30, reg_alpha=0, reg_lambda=1, subsample=0.9298306856179669;, score=-0.037 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8036083300300916, learning_rate=0.1, min_child_samples=142, min_child_weight=0.045013327015118905, n_estimators=250, num_leaves=30, reg_alpha=0, reg_lambda=1, subsample=0.9298306856179669;, score=-0.119 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8070921066042493, learning_rate=0.005, min_child_samples=221, min_child_weight=0.0776096879124342, n_estimators=1500, num_leaves=16, reg_alpha=10, reg_lambda=0, subsample=0.8721426234852072;, score=-0.028 total time=   1.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8070921066042493, learning_rate=0.005, min_child_samples=221, min_child_weight=0.0776096879124342, n_estimators=1500, num_leaves=16, reg_alpha=10, reg_lambda=0, subsample=0.8721426234852072;, score=-0.030 total time=   1.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8070921066042493, learning_rate=0.005, min_child_samples=221, min_child_weight=0.0776096879124342, n_estimators=1500, num_leaves=16, reg_alpha=10, reg_lambda=0, subsample=0.8721426234852072;, score=-0.037 total time=   1.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8070921066042493, learning_rate=0.005, min_child_samples=221, min_child_weight=0.0776096879124342, n_estimators=1500, num_leaves=16, reg_alpha=10, reg_lambda=0, subsample=0.8721426234852072;, score=-0.109 total time=   2.0s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9509983031499232, learning_rate=0.05, min_child_samples=130, min_child_weight=0.05797630930029188, n_estimators=1500, num_leaves=18, reg_alpha=0.1, reg_lambda=50, subsample=0.8733194262446914;, score=-0.028 total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9509983031499232, learning_rate=0.05, min_child_samples=130, min_child_weight=0.05797630930029188, n_estimators=1500, num_leaves=18, reg_alpha=0.1, reg_lambda=50, subsample=0.8733194262446914;, score=-0.030 total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9509983031499232, learning_rate=0.05, min_child_samples=130, min_child_weight=0.05797630930029188, n_estimators=1500, num_leaves=18, reg_alpha=0.1, reg_lambda=50, subsample=0.8733194262446914;, score=-0.037 total time=   1.2s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9509983031499232, learning_rate=0.05, min_child_samples=130, min_child_weight=0.05797630930029188, n_estimators=1500, num_leaves=18, reg_alpha=0.1, reg_lambda=50, subsample=0.8733194262446914;, score=-0.119 total time=   1.8s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9936502578265441, learning_rate=0.005, min_child_samples=161, min_child_weight=0.1035157532139525, n_estimators=1000, num_leaves=49, reg_alpha=1, reg_lambda=1, subsample=0.8728361203623017;, score=-0.028 total time=   1.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9936502578265441, learning_rate=0.005, min_child_samples=161, min_child_weight=0.1035157532139525, n_estimators=1000, num_leaves=49, reg_alpha=1, reg_lambda=1, subsample=0.8728361203623017;, score=-0.030 total time=   1.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9936502578265441, learning_rate=0.005, min_child_samples=161, min_child_weight=0.1035157532139525, n_estimators=1000, num_leaves=49, reg_alpha=1, reg_lambda=1, subsample=0.8728361203623017;, score=-0.037 total time=   2.7s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9936502578265441, learning_rate=0.005, min_child_samples=161, min_child_weight=0.1035157532139525, n_estimators=1000, num_leaves=49, reg_alpha=1, reg_lambda=1, subsample=0.8728361203623017;, score=-0.117 total time=   1.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9289550470368416, learning_rate=0.001, min_child_samples=193, min_child_weight=0.040344624662475306, n_estimators=100, num_leaves=4, reg_alpha=2, reg_lambda=0.1, subsample=0.9870341874404565;, score=-0.028 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9289550470368416, learning_rate=0.001, min_child_samples=193, min_child_weight=0.040344624662475306, n_estimators=100, num_leaves=4, reg_alpha=2, reg_lambda=0.1, subsample=0.9870341874404565;, score=-0.030 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9289550470368416, learning_rate=0.001, min_child_samples=193, min_child_weight=0.040344624662475306, n_estimators=100, num_leaves=4, reg_alpha=2, reg_lambda=0.1, subsample=0.9870341874404565;, score=-0.040 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9289550470368416, learning_rate=0.001, min_child_samples=193, min_child_weight=0.040344624662475306, n_estimators=100, num_leaves=4, reg_alpha=2, reg_lambda=0.1, subsample=0.9870341874404565;, score=-0.047 total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8324858282994767, learning_rate=0.05, min_child_samples=391, min_child_weight=0.10775268745498923, n_estimators=1500, num_leaves=38, reg_alpha=0, reg_lambda=5, subsample=0.9985124358343871;, score=-0.028 total time=   2.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8324858282994767, learning_rate=0.05, min_child_samples=391, min_child_weight=0.10775268745498923, n_estimators=1500, num_leaves=38, reg_alpha=0, reg_lambda=5, subsample=0.9985124358343871;, score=-0.030 total time=   2.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8324858282994767, learning_rate=0.05, min_child_samples=391, min_child_weight=0.10775268745498923, n_estimators=1500, num_leaves=38, reg_alpha=0, reg_lambda=5, subsample=0.9985124358343871;, score=-0.037 total time=   2.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8324858282994767, learning_rate=0.05, min_child_samples=391, min_child_weight=0.10775268745498923, n_estimators=1500, num_leaves=38, reg_alpha=0, reg_lambda=5, subsample=0.9985124358343871;, score=-0.047 total time=   2.3s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8695771684489257, learning_rate=0.05, min_child_samples=83, min_child_weight=0.1007992212579562, n_estimators=250, num_leaves=3, reg_alpha=0.1, reg_lambda=5, subsample=0.9125773576101656;, score=-0.028 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8695771684489257, learning_rate=0.05, min_child_samples=83, min_child_weight=0.1007992212579562, n_estimators=250, num_leaves=3, reg_alpha=0.1, reg_lambda=5, subsample=0.9125773576101656;, score=-0.030 total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8695771684489257, learning_rate=0.05, min_child_samples=83, min_child_weight=0.1007992212579562, n_estimators=250, num_leaves=3, reg_alpha=0.1, reg_lambda=5, subsample=0.9125773576101656;, score=-0.037 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8695771684489257, learning_rate=0.05, min_child_samples=83, min_child_weight=0.1007992212579562, n_estimators=250, num_leaves=3, reg_alpha=0.1, reg_lambda=5, subsample=0.9125773576101656;, score=-0.119 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.8299559332997967, learning_rate=0.2, min_child_samples=498, min_child_weight=0.10673769718332171, n_estimators=500, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.8289782833256498;, score=-0.028 total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.8299559332997967, learning_rate=0.2, min_child_samples=498, min_child_weight=0.10673769718332171, n_estimators=500, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.8289782833256498;, score=-0.030 total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.8299559332997967, learning_rate=0.2, min_child_samples=498, min_child_weight=0.10673769718332171, n_estimators=500, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.8289782833256498;, score=-0.037 total time=   1.0s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.8299559332997967, learning_rate=0.2, min_child_samples=498, min_child_weight=0.10673769718332171, n_estimators=500, num_leaves=13, reg_alpha=0, reg_lambda=0, subsample=0.8289782833256498;, score=-0.048 total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.9544790765723848, learning_rate=0.005, min_child_samples=369, min_child_weight=0.04702847728410065, n_estimators=250, num_leaves=25, reg_alpha=0, reg_lambda=0.1, subsample=0.9013292522743391;, score=-0.028 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.9544790765723848, learning_rate=0.005, min_child_samples=369, min_child_weight=0.04702847728410065, n_estimators=250, num_leaves=25, reg_alpha=0, reg_lambda=0.1, subsample=0.9013292522743391;, score=-0.030 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.9544790765723848, learning_rate=0.005, min_child_samples=369, min_child_weight=0.04702847728410065, n_estimators=250, num_leaves=25, reg_alpha=0, reg_lambda=0.1, subsample=0.9013292522743391;, score=-0.038 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.9544790765723848, learning_rate=0.005, min_child_samples=369, min_child_weight=0.04702847728410065, n_estimators=250, num_leaves=25, reg_alpha=0, reg_lambda=0.1, subsample=0.9013292522743391;, score=-0.048 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 1/4] END colsample_bytree=0.815628051582106, learning_rate=0.005, min_child_samples=178, min_child_weight=0.08494278828693078, n_estimators=250, num_leaves=17, reg_alpha=0.1, reg_lambda=5, subsample=0.8779142973175403;, score=-0.028 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 2/4] END colsample_bytree=0.815628051582106, learning_rate=0.005, min_child_samples=178, min_child_weight=0.08494278828693078, n_estimators=250, num_leaves=17, reg_alpha=0.1, reg_lambda=5, subsample=0.8779142973175403;, score=-0.030 total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 3/4] END colsample_bytree=0.815628051582106, learning_rate=0.005, min_child_samples=178, min_child_weight=0.08494278828693078, n_estimators=250, num_leaves=17, reg_alpha=0.1, reg_lambda=5, subsample=0.8779142973175403;, score=-0.038 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# [CV 4/4] END colsample_bytree=0.815628051582106, learning_rate=0.005, min_child_samples=178, min_child_weight=0.08494278828693078, n_estimators=250, num_leaves=17, reg_alpha=0.1, reg_lambda=5, subsample=0.8779142973175403;, score=-0.081 total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gpu_device
# RandomizedSearchCV(cv=4, estimator=LGBMRegressor(device='gpu', gpu_device=0),
#                    n_iter=25,
#                    param_distributions={'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7d2dcb13b6a0>,
#                                         'learning_rate': [0.001, 0.005, 0.01,
#                                                           0.05, 0.1, 0.2],
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7d2e7c4fb1c0>,
#                                         'min_child_weight': <s...ructure.rv_frozen object at 0x7d2e713a2b60>,
#                                         'n_estimators': [100, 250, 500, 1000,
#                                                          1500],
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7d2e713a12d0>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10],
#                                         'reg_lambda': [0, 0.1, 1, 5, 10, 20,
#                                                        50],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7d2e7c4f9240>},
#                    scoring='neg_mean_squared_error', verbose=4)

# %%
best_lgbm = random_search.best_estimator_

# %%
random_search.best_params_
# Out:
# {'colsample_bytree': 0.9961676915049176,
#  'learning_rate': 0.1,
#  'min_child_samples': 237,
#  'min_child_weight': 0.09198541565307419,
#  'n_estimators': 500,
#  'num_leaves': 34,
#  'reg_alpha': 0.1,
#  'reg_lambda': 0,
#  'subsample': 0.9630288148888715}

# %%
train_preds_lgb = best_lgbm.predict(X_train)

preds_lgb = best_lgbm.predict(X_test)

# Calculating R² scores
r2_lgb = r2_score(y_test, preds_lgb)

r2_train_lgb=r2_score(y_train, train_preds_lgb)

print("R² Scores Train:")
print(f"LGBM: {r2_train_lgb}")

print("R² Scores Test:")
print(f"LGBM: {r2_lgb}")
# Out:
# R² Scores Train:
# LGBM: 0.05275089918397746
# R² Scores Test:
# LGBM: 0.2729291941547807

# %%
def rank_configurations(predictions, full_df):
    ranked_configurations = []

    # Create a mapping of DataFrame indices to the range of indices in predictions
    index_mapping = {idx: i for i, idx in enumerate(full_df.index)}

    # Group data by 'config_id' and process each group
    for config_id, group in full_df.groupby('config_id'):
        # Get the corresponding prediction indices for the current group
        prediction_indices = [index_mapping[idx] for idx in group.index]

        # Rank configurations by predicted runtime
        ranked_indices = group.index[np.argsort(predictions[prediction_indices])]

        # Store the original indices of the ranked configurations
        ranked_configurations.append(list(ranked_indices))

    return ranked_configurations
def calculate_top_k_slowdown(predicted_rankings, full_df, runtime_column='runtime', k=5):
    total_slowdown = 0
    num_models = len(predicted_rankings)

    for predicted in tqdm(predicted_rankings):
        # Extract the top-k predicted configurations
        top_k_predicted = predicted[:k]

        # Best runtime among top-k predicted configurations
        best_runtime_top_k = full_df.loc[top_k_predicted, runtime_column].min()

        # Best runtime among all configurations in the model group
        config_id = full_df.loc[top_k_predicted[0], 'config_id']
        best_runtime_all = full_df[full_df['config_id'] == config_id][runtime_column].min()

        # Calculate slowdown for this model
        slowdown = 1 - ((best_runtime_top_k / best_runtime_all) - 1)
        total_slowdown += slowdown

    # Average slowdown across all models
    average_slowdown = total_slowdown / num_models
    return average_slowdown

# %%
epsilon = 1e-3  # Small value to add to zero runtimes

# Adjusting the 'runtime' column in train_df and test_df
train_df['runtime'] = train_df['runtime'].apply(lambda x: x if x != 0 else x + epsilon)
test_df['runtime'] = test_df['runtime'].apply(lambda x: x if x != 0 else x + epsilon)
# Out:
# /tmp/ipykernel_42/3909158171.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['runtime'] = train_df['runtime'].apply(lambda x: x if x != 0 else x + epsilon)
# /tmp/ipykernel_42/3909158171.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['runtime'] = test_df['runtime'].apply(lambda x: x if x != 0 else x + epsilon)

# %%
# Use the existing predictions to rank configurations
ranked_train_lr = rank_configurations(train_predictions_lin, train_df)
ranked_test_lr = rank_configurations(predictions_lin, test_df)

ranked_train_lasso = rank_configurations(train_predictions_lasso, train_df)
ranked_test_lasso = rank_configurations(predictions_lasso, test_df)

ranked_train_ridge = rank_configurations(train_predictions_ridge, train_df)
ranked_test_ridge = rank_configurations(predictions_ridge, test_df)

ranked_train_lgbm = rank_configurations(train_preds_lgb, train_df)
ranked_test_lgbm = rank_configurations(preds_lgb, test_df)

true_ranked_train = rank_configurations(y_train.to_numpy(), train_df)
true_ranked_test = rank_configurations(y_test.to_numpy(), test_df)

# Calculate and print the average top-k slowdown for the train predictions
average_slowdown_lr_train = calculate_top_k_slowdown(ranked_train_lr, train_df)
average_slowdown_lasso_train = calculate_top_k_slowdown(ranked_train_lasso, train_df)
average_slowdown_ridge_train = calculate_top_k_slowdown(ranked_train_ridge, train_df)
average_slowdown_lgbm_train = calculate_top_k_slowdown(ranked_train_lgbm, train_df)

print("Average Top-k Slowdown (LR, Train):", average_slowdown_lr_train)
print("Average Top-k Slowdown (Lasso, Train):", average_slowdown_lasso_train)
print("Average Top-k Slowdown (Ridge, Train):", average_slowdown_ridge_train)
print("Average Top-k Slowdown (LGBM, Train):", average_slowdown_lgbm_train)

# Calculate and print the average top-k slowdown for the test predictions
average_slowdown_lr_test = calculate_top_k_slowdown(ranked_test_lr, test_df)
average_slowdown_lasso_test = calculate_top_k_slowdown(ranked_test_lasso, test_df)
average_slowdown_ridge_test = calculate_top_k_slowdown(ranked_test_ridge, test_df)
average_slowdown_lgbm_test = calculate_top_k_slowdown(ranked_test_lgbm, test_df)

print("Average Top-k Slowdown (LR, Test):", average_slowdown_lr_test)
print("Average Top-k Slowdown (Lasso, Test):", average_slowdown_lasso_test)
print("Average Top-k Slowdown (Ridge, Test):", average_slowdown_ridge_test)
print("Average Top-k Slowdown (LGBM, Test):", average_slowdown_lgbm_test)
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 101.32it/s]
# 100%|██████████| 6/6 [00:00<00:00, 102.06it/s]
# 100%|██████████| 6/6 [00:00<00:00, 102.86it/s]
# 100%|██████████| 6/6 [00:00<00:00, 102.70it/s]
# Average Top-k Slowdown (LR, Train): -54.65356033924483
# Average Top-k Slowdown (Lasso, Train): -111.33296888100442
# Average Top-k Slowdown (Ridge, Train): -54.65356033924483
# Average Top-k Slowdown (LGBM, Train): -51.382065562165934
# 100%|██████████| 1/1 [00:00<00:00, 292.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 169.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 352.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 386.39it/s]
# Average Top-k Slowdown (LR, Test): -108.47818290451092
# Average Top-k Slowdown (Lasso, Test): -35716.980673294915
# Average Top-k Slowdown (Ridge, Test): -112.51145646496042
# Average Top-k Slowdown (LGBM, Test): -110.82068141018068

# %%
#ranked_train_lgbm[0]
train_df['runtime']
# Out:
# 8085     0.297965
# 8086     0.298058
# 8087     0.297518
# 8088     0.298140
# 8089     0.298250
#            ...
# 66016    0.064773
# 66017    0.000451
# 66018    0.000313
# 66019    0.434318
# 66020    0.001615
# Name: runtime, Length: 57936, dtype: float64
